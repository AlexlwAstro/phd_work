# %%
import numpy as np
import matplotlib.pyplot as plt

omega_init = []
theta_init = []
x = []

for i in range (0,22):
    omega_init.append(i*0.05)
omega = np.array(omega_init)
print omega

for i in range (0,19):
    theta_init.append(i*20)
omega = np.array(omega_init)
print omega
#assume sin(theta) = 1
for i in range(len(omega)):
    for j in range(len(theta)):
        xval = (3/(omega[i]*np.sin(theta[j]))*np.cos((np.pi + np.arccos(omega[i]np.sin(theta[j])))/3)
        x.append(xval)
x_final = np.array(x)

fig,rot = plt.subplots()
rot.plot(omega,x_final)
plt.show()
# Out:
# [ 0.    0.05  0.1   0.15  0.2   0.25  0.3   0.35  0.4   0.45  0.5   0.55
#   0.6   0.65  0.7   0.75  0.8   0.85  0.9   0.95  1.    1.05]
# C:\Users\User\Anaconda2\lib\site-packages\ipykernel\__main__.py:13: RuntimeWarning: divide by zero encountered in double_scalars
# C:\Users\User\Anaconda2\lib\site-packages\ipykernel\__main__.py:13: RuntimeWarning: invalid value encountered in arccos
