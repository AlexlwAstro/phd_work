# %%
import numpy as np
from matplotlib import pyplot as plt
print 'done'
# Out:
# done

# %%
# list of sample sizes, to compare

ss_list = [100,200,500,1000,2000,5000,10000,15000]
#pi_test = []
x_list = []
y_list = []
r_list = []
x_lt1_list = []
y_lt1_list = []
r_lt1_list = []


for k in range(len(ss_list)):
    x = []
    y = []
    r = []
    sample_size = ss_list[k]
    for i in range(sample_size):
        xval = np.random.random()
        yval = np.random.random()
        x.append(xval)
        y.append(yval)
        r.append(xval**2 + yval**2)
    print type(x),type(x[0])
    print min(x),max(x)
    print min(y),max(y)
    print min(r),max(r)

    inds = []
    for i in range(len(r)):
        if (r[i] > 1.0):
            inds.append(i)
    print len(inds)
    print len(x),len(y),len(r)

    x_lt1 = [x[i] for i in range(len(r)) if not (r[i] > 1.0)]
    y_lt1 = [y[i] for i in range(len(r)) if not (r[i] > 1.0)]
    r_lt1 = [r[i] for i in range(len(r)) if not (r[i] > 1.0)]
    print len(x_lt1),len(y_lt1),len(r_lt1)

    #for i in range(len(x_lt1)):
    #    print x_lt1[i]**2 + y_lt1[i]**2

    x_lim = np.linspace(0,1,101)
    y_lim = np.sqrt(1.0 - x_lim**2)

    print min(x_lim),min(y_lim)
    print max(x_lim),max(y_lim)

    # find approx. value of pi, which is (area of quadrant/radius^2)
    pi_test = 4.0*(float(len(y_lt1))/float(len(y)))
    print 'FINAL PREDICTION'
    print 'number of points = '+str(sample_size)+' , estimated value of pi = '+str(pi_test)
    print '\n'
    
    fig,ax = plt.subplots(figsize=(8,8))
    ax.set_xlabel('x')
    ax.set_ylabel('y')
    ax.set_xlim(0.0,1.0)
    ax.set_ylim(0.0,1.0)
    ax.plot(x_lim,y_lim,'g')
    ax.scatter(x_lt1,y_lt1,color='b',marker='x')
# Out:
# <type 'list'> <type 'float'>
# 0.0039817244844 0.998336903235
# 0.0022164121217 0.999880755183
# 0.0339486327097 1.86269326534
# 20
# 100 100 100
# 80 80 80
# 0.0 0.0
# 1.0 1.0
# FINAL PREDICTION
# number of points = 100 , estimated value of pi = 3.2
#
#
# <type 'list'> <type 'float'>
# 0.0046710088361 0.999543139472
# 0.000619010535552 0.989737071153
# 0.00435568985258 1.85062191751
# 45
# 200 200 200
# 155 155 155
# 0.0 0.0
# 1.0 1.0
# FINAL PREDICTION
# number of points = 200 , estimated value of pi = 3.1
#
#
# <type 'list'> <type 'float'>
# 0.0020232112921 0.983891245675
# 0.000108503750161 0.999127385676
# 0.00452163836081 1.93319536963
# 97
# 500 500 500
# 403 403 403
# 0.0 0.0
# 1.0 1.0
# FINAL PREDICTION
# number of points = 500 , estimated value of pi = 3.224
#
#
# <type 'list'> <type 'float'>
# 0.000262635863707 0.994929309418
# 0.00116601342718 0.999388636383
# 0.00452030917076 1.88932887407
# 196
# 1000 1000 1000
# 804 804 804
# 0.0 0.0
# 1.0 1.0
# FINAL PREDICTION
# number of points = 1000 , estimated value of pi = 3.216
#
#
# <type 'list'> <type 'float'>
# 0.000884151824825 0.999991841336
# 0.000377226913273 0.999171046682
# 0.000783578339675 1.92116194268
# 422
# 2000 2000 2000
# 1578 1578 1578
# 0.0 0.0
# 1.0 1.0
# FINAL PREDICTION
# number of points = 2000 , estimated value of pi = 3.156
#
#
# <type 'list'> <type 'float'>
# 7.7840599907e-05 0.999972449593
# 7.21574308311e-05 0.999843907783
# 0.000275783579014 1.99032205535
# 1081
# 5000 5000 5000
# 3919 3919 3919
# 0.0 0.0
# 1.0 1.0
# FINAL PREDICTION
# number of points = 5000 , estimated value of pi = 3.1352
#
#
# <type 'list'> <type 'float'>
# 6.31086605184e-05 0.99999267825
# 1.73560516049e-05 0.999907853088
# 0.000238737586573 1.97720222617
# 2187
# 10000 10000 10000
# 7813 7813 7813
# 0.0 0.0
# 1.0 1.0
# FINAL PREDICTION
# number of points = 10000 , estimated value of pi = 3.1252
#
#
# <type 'list'> <type 'float'>
# 8.94650668621e-05 0.999963978197
# 8.40676755931e-06 0.999974191304
# 3.43363767766e-05 1.98721713005
# 3219
# 15000 15000 15000
# 11781 11781 11781
# 0.0 0.0
# 1.0 1.0
# FINAL PREDICTION
# number of points = 15000 , estimated value of pi = 3.1416
